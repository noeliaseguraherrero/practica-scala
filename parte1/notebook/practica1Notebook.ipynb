// %%
scala.util.Properties.versionNumberString
// Out:
// res2: String = "2.12.21"

// %%
println(scala.util.Properties.versionMsg)
// Out:
// Scala library version 2.12.21 -- Copyright 2002-2025, LAMP/EPFL and Lightbend, Inc. dba Akka

// %%
val nombre = "Scala"
val version = "2.12.21"

println(s"Hola desde $nombre $version")
// Out:
// Hola desde Scala 2.12.21
// nombre: String = "Scala"
// version: String = "2.12.21"

// %%
val a = 10
val b = 20
val resultado = a + b

println(resultado)
// Out:
// 30
// a: Int = 10
// b: Int = 20
// resultado: Int = 30

// %%
val lenguajes = List("Scala", "Java", "Python")

println(lenguajes)
// Out:
// List(Scala, Java, Python)
// lenguajes: List[String] = List("Scala", "Java", "Python")
